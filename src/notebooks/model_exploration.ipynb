# %%
import sys

sys.path.append('/Users/rileymcnamara/CODE/2025/SCIE3212/')

# %% [markdown]
# <h2> Organoid Growth Model </h2>
#
# To use the organoid growth simulation a simulation can be run, saved, loaded and analysed in the following manner.

# %%
from src.models.tumor_growth import TumorGrowthModel
from analysis.simulation_analysis import SimulationAnalyzer, compute_total_volumes

#model = TumorGrowthModel(grid_size = (100, 100, 100), dx = 0.025, dt = 0.001)
#model.run_and_save_simulation(steps = 200, filename = "28/2/2025")
analyzer = SimulationAnalyzer('/Users/rileymcnamara/CODE/2025/SCIE3212/data/spherical_tumor_2_sim_data.npz')

# %% [markdown]
# A simulation can then be analysed using the SimulationAnalyzer. Observables such as the total volume of each cell populations and the radius of the tumor, over the course of the simulation can be plotted.

# %%
print(analyzer.get_simulation_metadata())

analyzer.plot_volumes()
# Out:
# {'dx': 0.1, 'dt': 0.001, 'steps': 200, 'save_steps': 10}

# %%
analyzer.plot_radius()

# %%
analyzer.plot_growth_rate() # plot final step

# %%
analyzer.plot_cross_section(-1, cell_type='differentiated')
analyzer.plot_cross_section(-1, cell_type='healthy')
analyzer.plot_cross_section(-1, cell_type='progenitor')
analyzer.plot_cross_section(-1, cell_type='necrotic')

# %%
analyzer.plot_3d_at_step(-1, mode="isosurface")
