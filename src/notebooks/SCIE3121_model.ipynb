# %%
import sys

sys.path.append('/Users/rileymcnamara/CODE/2025/SCIE3212/')

# %%
from src.models.SCIE3121_model import SCIE3121_MODEL
from analysis.scie3121_analysis import scie3121SimulationAnalyzer, compute_total_volumes
from src.models.initial_conditions import SphericalTumor

grid_shape = (100, 100, 100)
dx = 0.1
dt = 0.0001
steps = 300

#initial_conditions = SphericalTumor(grid_shape)
#model = SCIE3121_MODEL(grid_shape, dx, dt, initial_conditions)
#model.run_and_save_simulation(steps, 'test_simulation')

# %%
analyzer = scie3121SimulationAnalyzer('/Users/rileymcnamara/CODE/2025/SCIE3212/data/project_model_test_sim_data.npz')
analyzer.plot_volumes()
analyzer.plot_radius()
analyzer.plot_growth_rate()
analyzer.plot_cross_section(0, 'healthy')
analyzer.plot_cross_section(-1, 'healthy')
analyzer.plot_cross_section(0, 'diseased')
analyzer.plot_cross_section(-1, 'diseased')
analyzer.plot_cross_section(0, 'necrotic')
analyzer.plot_cross_section(-1, 'necrotic')
analyzer.plot_cross_section(0, 'total')
analyzer.plot_cross_section(-1, 'total')
# Out:
# dict_keys(['step', 'healthy cell volume fraction', 'diseased cell volume fraction', 'necrotic cell volume fraction', 'nutrient concentration', 'Simulation Metadata'])
# /Users/rileymcnamara/CODE/2025/SCIE3212/scie3212/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 13
#      11 analyzer.plot_cross_section(0, 'total')
#      12 analyzer.plot_cross_section(-1, 'total')
# ---> 13 analyzer.plot_3d_at_step(-1)
#
# File ~/CODE/2025/SCIE3212/analysis/scie3121_analysis.py:158, in scie3121SimulationAnalyzer.plot_3d_at_step(self, step_index, levels, colors, mode)
#     156 ax.set_title(f'3D Tumor Visualization at Step {step_index} ({mode})')
#     157 ax.legend()
# ...
