# %%
import sys

sys.path.append('/Users/rileymcnamara/CODE/2025/SCIE3212/')

# %%
from analysis.scie3121_analysis import scie3121SimulationAnalyzer

# %%
analyzer = scie3121SimulationAnalyzer('/Users/rileymcnamara/CODE/2025/SCIE3212/data/project_model_test_sim_data.npz')
analyzer.plot_volumes()
analyzer.plot_radius()
analyzer.plot_population_radii(threshold=0.1, smooth_window=5)
analyzer.plot_growth_rate()
analyzer.plot_cross_section(0, 'healthy', index=None)
analyzer.plot_cross_section(-1, 'healthy', index=None)
analyzer.plot_cross_section(0, 'diseased', index=None)
analyzer.plot_cross_section(-1, 'diseased', index=None)
analyzer.plot_cross_section(0, 'necrotic', index=None)
analyzer.plot_cross_section(-1, 'necrotic', index=None)
analyzer.plot_cross_section(0, 'total', index=None)
analyzer.plot_cross_section(-1, 'total', index=None)
