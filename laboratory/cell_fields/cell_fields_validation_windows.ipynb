# %% [markdown]
# # Cell Field Population Plotting
#
# This notebook is to be used to plot the cell volume fraction fields for validation.

# %%
from pathlib import Path
import sys

proj = Path(r"C:\Users\riley.mcnamara\Documents\code\SCIE3212")
assert (proj / "src").exists(), f"No 'src' at {proj}"

sys.path.insert(0, str(proj))

from src.growkit.Simulator import TumorGrowthSimulator
from src.growkit.PlotEngine.CellFieldPlotter import CellFieldPlotter

simulator = TumorGrowthSimulator(r"C:\Users\riley.mcnamara\Documents\code\SCIE3212\templates\test_templates\physics_fields_analysis.yaml")

simulation_data = simulator.load_simulation_data(r"C:\Users\riley.mcnamara\Documents\code\SCIE3212\laboratory\saved_simulations\simulation_data.npz")
cell_field_plotter = CellFieldPlotter(simulation_data, simulator=simulator)
# Out:
# Pre-compiling Numba functions...
# Numba functions compiled successfully!
# Loading simulation data from C:\Users\riley.mcnamara\Documents\code\SCIE3212\laboratory\saved_simulations\simulation_data.npz...
# Loaded simulation data with 4 saved steps

# %%
cell_field_plotter.plot_population_by_label(simulation_data, label="Necrotic Cells", step_idx=0, z_slice=None, show_plot=True)
# Out:
# Plotting population 'Necrotic Cells' for step 0 (time=0.000)...
# Found population 'Necrotic Cells' at index 2

# %%
cell_field_plotter.plot_population_evolution_by_label(simulation_data, label="Stem Cells", cmap="BuPu", show_plot=True)
# Out:
# Plotting evolution for population: Stem Cells (index: 0)
# Available population labels: ['Stem Cells', 'Tumour Cells', 'Necrotic Cells']
# Step indices: [0, 1, 2, 3]
