# %% [markdown]
# # Template Simulation
#
# This file displays how to run a simulation with the growkit software in a Jupyter notebook.
#
# First of all a simulation template YAML file must be specified and stored in the templates folder. See template.yaml for how to define a simulation.

# %%
import sys

sys.path.append('/Users/rileymcnamara/CODE/2025/SCIE3212/')

from src.growkit.Simulator import TumorGrowthSimulator

simulation_template = "/Users/rileymcnamara/CODE/2025/SCIE3212/templates/og.yaml"

simulator = TumorGrowthSimulator(simulation_template)
simulator.run()
