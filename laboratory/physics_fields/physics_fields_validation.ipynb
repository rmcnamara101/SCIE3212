# %% [markdown]
# # Physics Fields Validation
#
# This file shows validation of the physical fields visually. The pressure, the adhesion energy, the solid velocity, and mass flux fields are all displayed here.

# %%
import sys
from pathlib import Path

if sys.platform == "darwin":
    proj = "/Users/rileymcnamara/CODE/2025/silicokit/"
    sys.path.insert(0, proj)
else:
    proj = "C:/Users/riley.mcnamara/Documents/code/silicokit/"
    sys.path.insert(0, proj)

from src.growkit.Simulator import TumorGrowthSimulator
from src.growkit.PlotEngine.PhysicsFieldsPlotter import PhysicsFieldsPlotter

simulator = TumorGrowthSimulator(proj + "/configs/T_N.yaml")

simulation_data = simulator.load_simulation_data(proj + "/laboratory/saved_simulations/simulation_data.npz")

plotter = PhysicsFieldsPlotter.from_simulation_data(simulation_data)
# Out:
# Pre-compiling Numba functions...
# Numba functions compiled successfully!
# Loading simulation data from /Users/rileymcnamara/CODE/2025/silicokit//laboratory/saved_simulations/simulation_data.npz...
# Loaded simulation data with 11 saved steps

# %% [markdown]
# ### Here is the total tumour density for reference

# %%
plotter.plot_tumor_density_from_saved(simulation_data, step_idx=0, cmap="BuPu", z_slice=None, output_dir=None, save_plot=False, show_plot=True, add_contours=False, contour_population_idx=0, contour_levels=[0.1, 0.3, 0.5], contour_colors=['red', 'orange', 'yellow'], contour_linewidths=[2, 1.5, 1])
# Out:
# Plotting tumor density for step 0 (time=0.000) from saved data...

# %% [markdown]
# ## Pressure Scalar Field
#
# Plot of a slice through the centre of a circular tumour, of the pressure surface.
#
# Solution of the pressure equation, computed with scipy conjugate gradient solver.
#
# $$
# -\nabla^2p = S_T - \nabla \cdot \left ( \frac{\delta E}{\delta\varphi_i}\nabla\varphi_T \right )
# $$

# %%
plotter.plot_pressure_field_from_saved(simulation_data, step_idx=9, z_slice=None, output_dir=None, save_plot=False, show_plot=True, add_boundary_contours=False, tumor_boundary_level=0.5, boundary_color='darkblue', tumor_boundary_color='black', zoom_factor=2.0, center_x=48, center_y=48)
# Out:
# Plotting pressure field for step 9 (time=7.200) from saved data...

# %% [markdown]
# ## Solid Velocity Vector Field
#
# Plot of a slice through the centre of a circular tumour, of the vector field given by the equation:
#
# $$
# \mathbf{u_s}= -\left (\nabla p - \frac{\delta E}{\delta \varphi_i}\nabla\varphi_T \right )
# $$

# %%
plotter.plot_velocity_field_from_saved(simulation_data, step_idx=9, cmap="BuPu", skip=10, scale=10, width=0.003, arrow_density_factor=5.0, z_slice=None, output_dir=None, save_plot=False, show_plot=True, add_boundary_contours=True, tumor_boundary_level=0.5, boundary_color='darkblue', tumor_boundary_color='black', center_x=48, center_y=48, zoom_factor=2.0)
# Out:
# Plotting velocity field for step 9 (time=7.200) from saved data...

# %%
#plotter.plot_velocity_field_from_saved(simulation_data, step_idx=0, cmap="GnBu", skip=10, scale=20, width=0.003, arrow_density_factor=10.0, z_slice=None, output_dir=None, save_plot=False, show_plot=True, add_boundary_contours=True, tumor_boundary_level=0.5, boundary_color='darkblue', tumor_boundary_color='black', center_x=75, center_y=75, zoom_factor=3.0)

# %% [markdown]
# ## Adhesion Energy Scalar Field
#
# Plot through the centre of a circular tumour, of the adhesion energy scalar field given by the functional:
#
# $$
# E = m\int_\Omega \frac{1}{4}\varphi_T^2(1-\varphi_T)^2 + |\nabla\varphi_T|^2dx
# $$

# %%
plotter.plot_energy_derivative_field_from_saved(simulation_data, step_idx=0, z_slice=None, output_dir=None, save_plot=False, show_plot=True, add_boundary_contours=False, tumor_boundary_level=0.5, boundary_color='darkblue', tumor_boundary_color='black', center_x=48, center_y=48, zoom_factor=2.0)
# Out:
# Plotting energy derivative field for step 0 (time=0.000) from saved data...

# %% [markdown]
# ## Mass Flux Vector Field
#
# Plot through the centre of a circular tumour, of the Mass Flux vector field:
#
# $$
# J_i =-M_i\left ( \frac{\delta E}{\delta\varphi_T}\right )
# $$

# %%
plotter.plot_mass_flux_field_from_saved(simulation_data, step_idx=1, cmap="BuPu", skip=1, scale=0.01, width=0.005, arrow_density_factor=100.0, z_slice=None, output_dir=None, save_plot=False, show_plot=True, add_boundary_contours=True, tumor_boundary_level=0.1, boundary_color='darkblue', tumor_boundary_color='purple', center_x=48, center_y=48, zoom_factor=2.0)
# Out:
# Plotting mass flux field for population 0, step 1 (time=0.800) from saved data...

# %%
#plotter.plot_mass_flux_field_from_saved(simulation_data, step_idx=0, cmap="BuPu", skip=3, arrow_density_factor=30.0, scale=7, width=0.007, add_boundary_contours=True, center_x=75, center_y=75, zoom_factor=3.0, contour_shift_x=1, contour_shift_y=1)

# %%
plotter.plot_nutrient_field_from_saved(simulation_data, step_idx=4, z_slice=None, zoom_factor=3.0, center_x=48, center_y=48)
# Out:
# Plotting nutrient field for step 4 (time=3.200) from saved data...

# %%
plotter.plot_source_terms_from_saved(simulation_data, step_idx=3, cmap="GnBu", z_slice=None, show_plot=True, zoom_factor=3.0, center_x=48, center_y=48)
# Out:
# Plotting source terms for population 0, step 3 (time=2.400) from saved data...

# %%
plotter.plot_total_free_energy_evolution(simulation_data)

# %%
plotter.plot_nutrient_diffusion_over_time(simulation_data)
# Out:
# Nutrient Diffusion Analysis Summary:
# Initial penetration depth: 48.750
# Final penetration depth: 48.750
# Total change in penetration: 0.000
# Average penetration rate: 0.000 units/time

# %%
plotter.plot_nutrient_penetration_heatmap(simulation_data)
# Out:
# array([[0.66711611, 0.67466134, 0.86152947, 0.99698913, 0.99491841,
#         0.99665654, 0.99652189, 0.99738055, 0.99834704, 0.99755985,
#         0.9965024 , 0.99688452, 0.99713063, 0.99672419, 0.99649829,
#         0.99659789, 0.99634427, 0.99657947, 0.9961825 , 0.99685985],
#        [0.        , 0.        , 0.574718  , 0.9969697 , 0.99497372,
#         0.99660695, 0.99649245, 0.99731481, 0.9982655 , 0.99751955,
