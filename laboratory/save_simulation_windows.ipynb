# %%
from pathlib import Path
import sys

# Point to the actual project root that contains 'src'
proj = Path(r"C:\Users\riley.mcnamara\Documents\code\SCIE3212")
assert (proj / "src").exists(), f"No 'src' at {proj}"

# Prepend so it wins over anything else
sys.path.insert(0, str(proj))

from src.growkit.Simulator import TumorGrowthSimulator
from src.growkit.PlotEngine.PhysicsFieldsPlotter import PhysicsFieldsPlotter

# Use the YAML that actually exists under this repo
cfg = proj / "templates" / "test_templates" / "physics_fields_analysis.yaml"
simulator = TumorGrowthSimulator(str(cfg))
simulator.run_and_save_simulation(total_steps=3, save_interval=1, output_dir=r"C:\Users\riley.mcnamara\Documents\code\SCIE3212\laboratory\saved_simulations", save_physics_fields=True, save_plots=False)
# Out:
# Pre-compiling Numba functions...
# Numba functions compiled successfully!
# Starting tumor growth simulation with save/load functionality...
# Grid size: (80, 80, 80)
# Number of populations: 3
# Total time steps: 3
# Save interval: 1
# Time step size: 5
# Output directory: C:\Users\riley.mcnamara\Documents\code\SCIE3212\laboratory\saved_simulations
# Pressure solver time: 4.017384767532349 seconds (cache miss)
# Saved initial conditions (step 0, time 0.0)
# Source terms computation time: 0.0788111686706543 seconds
# Energy derivative computation time: 0.04766583442687988 seconds
# Pressure solver time: 1.8190796375274658 seconds (cache miss)
# Mass flux computation time: 0.0950767993927002 seconds
# Cell dynamics computation time: 10.215961456298828 seconds
# Energy derivative computation time: 0.031816720962524414 seconds
# Pressure solver time: 0.9437587261199951 seconds (cache miss)
# Mass flux computation time: 0.027657032012939453 seconds
# Cell dynamics computation time: 0.14261317253112793 seconds
# Energy derivative computation time: 0.014547348022460938 seconds
# Pressure solver time: 0.9020371437072754 seconds (cache miss)
# Mass flux computation time: 0.025881052017211914 seconds
# Cell dynamics computation time: 0.0951070785522461 seconds
# Energy derivative computation time: 0.03156757354736328 seconds
# Pressure solver time: 0.9349658489227295 seconds (cache miss)
# Mass flux computation time: 0.03184199333190918 seconds
# Cell dynamics computation time: 0.1427745819091797 seconds
# Pressure solver time: 2.059051275253296 seconds (cache miss)
# Saved data for step 1/3, Time: 5.000
# Source terms computation time: 0.06402277946472168 seconds
# Energy derivative computation time: 0.04784131050109863 seconds
# Pressure solver time: 1.0001261234283447 seconds (cache miss)
# Mass flux computation time: 0.11305356025695801 seconds
# Cell dynamics computation time: 3.2204337120056152 seconds
# Energy derivative computation time: 0.031951189041137695 seconds
# Pressure solver time: 0.9734084606170654 seconds (cache miss)
# Mass flux computation time: 0.1121368408203125 seconds
# Cell dynamics computation time: 0.11222124099731445 seconds
# Energy derivative computation time: 0.04173636436462402 seconds
# Pressure solver time: 1.0029261112213135 seconds (cache miss)
# Mass flux computation time: 0.0480198860168457 seconds
# Cell dynamics computation time: 0.12745332717895508 seconds
# Energy derivative computation time: 0.03180551528930664 seconds
# Pressure solver time: 0.9533772468566895 seconds (cache miss)
# Mass flux computation time: 0.06363844871520996 seconds
# Cell dynamics computation time: 0.11158943176269531 seconds
# Pressure solver time: 0.9332096576690674 seconds (cache miss)
# Saved data for step 2/3, Time: 10.000
# Source terms computation time: 0.07086801528930664 seconds
# Energy derivative computation time: 0.03484082221984863 seconds
# Pressure solver time: 0.9270050525665283 seconds (cache miss)
# Mass flux computation time: 0.06327104568481445 seconds
# Cell dynamics computation time: 0.14349102973937988 seconds
# Energy derivative computation time: 0.043190956115722656 seconds
# Pressure solver time: 0.9148459434509277 seconds (cache miss)
# Mass flux computation time: 0.05777096748352051 seconds
# Cell dynamics computation time: 0.154862642288208 seconds
# Energy derivative computation time: 0.03249478340148926 seconds
# Pressure solver time: 1.9047183990478516 seconds (cache miss)
# Mass flux computation time: 0.15330910682678223 seconds
# Cell dynamics computation time: 0.162492036819458 seconds
# Energy derivative computation time: 0.04596424102783203 seconds
# Pressure solver time: 1.7248849868774414 seconds (cache miss)
# Mass flux computation time: 0.09466910362243652 seconds
# Cell dynamics computation time: 0.24114990234375 seconds
# Pressure solver time: 1.818004846572876 seconds (cache miss)
# Saved data for step 3/3, Time: 15.000
# Simulation completed!
# Final time: 15.000
# Average step time: 14.172s
# Saved 4 data points
#
# Final performance summary:
#   total_step: 14.1721s avg (50.0%)
#   rk4_integration: 10.9953s avg (38.8%)
#   physics_fields_update: 3.0879s avg (10.9%)
#   source_terms_computation: 0.0712s avg (0.3%)
#   volume_fraction_normalization: 0.0177s avg (0.1%)
#   field_retrieval: 0.0000s avg (0.0%)
#   field_update: 0.0000s avg (0.0%)
#   Total average step time: 28.3442s
# Complete simulation data saved to C:\Users\riley.mcnamara\Documents\code\SCIE3212\laboratory\saved_simulations\simulation_data.npz
