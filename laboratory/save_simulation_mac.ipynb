# %%
import sys

sys.path.insert(0, "/Users/rileymcnamara/CODE/2025/SCIE3212/")

from src.growkit.Simulator import TumorGrowthSimulator

# Use the YAML that actually exists under this repo
cfg = "/Users/rileymcnamara/CODE/2025/SCIE3212/templates/test_templates/physics_fields_analysis.yaml"
simulator = TumorGrowthSimulator(str(cfg))
simulator.run_and_save_simulation(total_steps=5, save_interval=1, output_dir="/Users/rileymcnamara/CODE/2025/SCIE3212/laboratory/saved_simulations", save_physics_fields=True, save_plots=False)
# Out:
# Pre-compiling Numba functions...
# Numba functions compiled successfully!
# Starting tumor growth simulation with save/load functionality...
# Grid size: (80, 80, 80)
# Number of populations: 3
# Total time steps: 5
# Save interval: 1
# Time step size: 1
# Output directory: /Users/rileymcnamara/CODE/2025/SCIE3212/laboratory/saved_simulations
# Source terms computation time: 0.0036749839782714844 seconds
# Energy derivative computation time: 0.008118629455566406 seconds
# Pressure solver time: 0.23523306846618652 seconds (cache miss)
# Mass flux computation time: 0.014299154281616211 seconds
# Cell dynamics computation time: 0.04354095458984375 seconds
# Energy derivative computation time: 0.007193803787231445 seconds
# Pressure solver time: 0.21978235244750977 seconds (cache miss)
# Mass flux computation time: 0.00961923599243164 seconds
# Cell dynamics computation time: 0.04716897010803223 seconds
# Energy derivative computation time: 0.0077970027923583984 seconds
# ...
